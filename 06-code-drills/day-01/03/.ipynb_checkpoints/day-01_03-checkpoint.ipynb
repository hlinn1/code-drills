# %%
# Import your dependencies requests, json, and pprint for pretty printing.
import requests
import json
import pprint

# %%
# Create a variable called search_tv
    # Request for user input with the question "What show would you like?"
        # Example "friends" as an input
search_tv = input("What show would you like? ")
# Out:
# What show would you like? friends

# %%
# Create a variable called base_url and 
    # set it to the string below
    # "http://api.tvmaze.com/search/shows?q="
base_url = "http://api.tvmaze.com/search/shows?q="

# %%
# Set the variable 'response' to the data from base_url with search_tv appended
response = requests.get(base_url + search_tv)

# %%
# Create a variable called res_data 
    # Set it to the response converted as a json format
res_data = response.json()

# Using pprint, print the res_data
pprint.PrettyPrinter(indent=4).pprint(res_data)
# Out:
# [   {   'score': 19.094687,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/40881'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/431'}},
#                     'externals': {   'imdb': 'tt0108778',
#                                      'thetvdb': 79168,
#                                      'tvrage': 3616},
#                     'genres': ['Comedy', 'Romance'],
#                     'id': 431,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/41/104550.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/41/104550.jpg'},
#                     'language': 'English',
#                     'name': 'Friends',
#                     'network': {   'country': {   'code': 'US',
#                                                   'name': 'United States',
#                                                   'timezone': 'America/New_York'},
#                                    'id': 1,
#                                    'name': 'NBC'},
#                     'officialSite': None,
#                     'premiered': '1994-09-22',
#                     'rating': {'average': 8.7},
#                     'runtime': 30,
#                     'schedule': {'days': ['Thursday'], 'time': '20:00'},
#                     'status': 'Ended',
#                     'summary': '<p>Six young (20-something) people from New '
#                                'York City (Manhattan), on their own and '
#                                'struggling to survive in the real world, find '
#                                'the companionship, comfort and support they '
#                                'get from each other to be the perfect antidote '
#                                'to the pressures of life.</p><p>This average '
#                                'group of buddies goes through massive mayhem, '
#                                'family trouble, past and future romances, '
#                                'fights, laughs, tears and surprises as they '
#                                'learn what it really means to be a friend.</p>',
#                     'type': 'Scripted',
#                     'updated': 1532606311,
#                     'url': 'http://www.tvmaze.com/shows/431/friends',
#                     'webChannel': None,
#                     'weight': 91}},
#     {   'score': 14.032533,
#         'show': {   '_links': {   'nextepisode': {   'href': 'http://api.tvmaze.com/episodes/1514311'},
#                                   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1514310'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/33940'}},
#                     'externals': {   'imdb': 'tt4049416',
#                                      'thetvdb': 270112,
#                                      'tvrage': None},
#                     'genres': ['Comedy', 'Children'],
#                     'id': 33940,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/138/346444.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/138/346444.jpg'},
#                     'language': 'English',
#                     'name': 'LEGO Friends',
#                     'network': {   'country': {   'code': 'US',
#                                                   'name': 'United States',
#                                                   'timezone': 'America/New_York'},
#                                    'id': 78,
#                                    'name': 'Disney Channel'},
#                     'officialSite': None,
#                     'premiered': '2012-05-05',
#                     'rating': {'average': None},
#                     'runtime': 30,
#                     'schedule': {'days': [], 'time': ''},
#                     'status': 'Running',
#                     'summary': '<p>As a way to make friends, new girl in town '
#                                'Olivia volunteers to work at the Heartlake '
#                                'City World Petacular with four other '
#                                'girls.</p>',
#                     'type': 'Animation',
#                     'updated': 1534417943,
#                     'url': 'http://www.tvmaze.com/shows/33940/lego-friends',
#                     'webChannel': None,
#                     'weight': 80}},
#     {   'score': 13.986619,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1327333'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/6458'}},
#                     'externals': {   'imdb': 'tt0086815',
#                                      'thetvdb': 78949,
#                                      'tvrage': 6340},
#                     'genres': ['Children'],
#                     'id': 6458,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/24/61753.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/24/61753.jpg'},
#                     'language': 'English',
#                     'name': 'Thomas & Friends',
#                     'network': {   'country': {   'code': 'GB',
#                                                   'name': 'United Kingdom',
#                                                   'timezone': 'Europe/London'},
#                                    'id': 135,
#                                    'name': 'Channel 5'},
#                     'officialSite': 'http://www.channel5.com/show/thomas-and-friends',
#                     'premiered': '1984-10-09',
#                     'rating': {'average': None},
#                     'runtime': 15,
#                     'schedule': {   'days': [   'Monday',
#                                                 'Tuesday',
#                                                 'Wednesday',
#                                                 'Thursday',
#                                                 'Friday'],
#                                     'time': '07:20'},
#                     'status': 'Running',
#                     'summary': '<p><b>Thomas &amp; Friends</b> is a British '
#                                "children's television series, which had its "
#                                'first broadcast on the ITV network on 9 '
#                                'October 1984. It is based on The Railway '
#                                'Series of books by the Reverend Wilbert Awdry '
#                                'and his son, Christopher Awdry. These books '
#                                'deal with the adventures of a group of '
#                                'anthropomorphised locomotives and road '
#                                'vehicles who live on the fictional Island of '
#                                'Sodor. The books were based on stories Wilbert '
#                                'told to entertain his son, Christopher during '
#                                'his recovery from measles. From Series one to '
#                                'four, many of the stories are based on events '
#                                "from Awdry's personal experience.</p>",
#                     'type': 'Animation',
#                     'updated': 1513725505,
#                     'url': 'http://www.tvmaze.com/shows/6458/thomas-friends',
#                     'webChannel': None,
#                     'weight': 63}},
#     {   'score': 13.952411,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1511358'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/33879'}},
#                     'externals': {   'imdb': None,
#                                      'thetvdb': 343514,
#                                      'tvrage': None},
#                     'genres': [],
#                     'id': 33879,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/147/369465.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/147/369465.jpg'},
#                     'language': 'English',
#                     'name': 'Jane & Friends',
#                     'network': {   'country': {   'code': 'GB',
#                                                   'name': 'United Kingdom',
#                                                   'timezone': 'Europe/London'},
#                                    'id': 135,
#                                    'name': 'Channel 5'},
#                     'officialSite': 'http://www.channel5.com/show/jane-mcdonald-friends/',
#                     'premiered': '2018-03-09',
#                     'rating': {'average': None},
#                     'runtime': 60,
#                     'schedule': {'days': ['Friday'], 'time': '21:00'},
#                     'status': 'Running',
#                     'summary': '<p><b>Jane &amp; Friends</b> is a variety show '
#                                'in which Jane McDonald performs her favourite '
#                                'songs with her live band. The audience is an '
#                                'integral part of the programme, joining in the '
#                                'songs and sharing the banter. Jane is joined '
#                                'by guest artists and groups performing current '
#                                'songs, classic hits and occasionally duets '
#                                'with Jane herself.</p>',
#                     'type': 'Variety',
#                     'updated': 1533933656,
#                     'url': 'http://www.tvmaze.com/shows/33879/jane-friends',
#                     'webChannel': None,
#                     'weight': 82}},
#     {   'score': 12.72258,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1260315'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/30774'}},
#                     'externals': {   'imdb': 'tt0315608',
#                                      'thetvdb': 99721,
#                                      'tvrage': None},
#                     'genres': ['Drama', 'Romance'],
#                     'id': 30774,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/122/305714.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/122/305714.jpg'},
#                     'language': 'Japanese',
#                     'name': 'Friends',
#                     'network': {   'country': {   'code': 'JP',
#                                                   'name': 'Japan',
#                                                   'timezone': 'Asia/Tokyo'},
#                                    'id': 159,
#                                    'name': 'TBS'},
#                     'officialSite': 'http://www.tbs.co.jp/friends21/',
#                     'premiered': '2002-02-04',
#                     'rating': {'average': None},
#                     'runtime': 65,
#                     'schedule': {   'days': ['Monday', 'Tuesday'],
#                                     'time': '21:00'},
#                     'status': 'Ended',
#                     'summary': '<p>Left alone on a trip to Hong Kong, Tomoko '
#                                'finds herself the victim of a purse-snatching. '
#                                'The police arrest the man she points out, but '
#                                'it turns out to be the wrong person: a young '
#                                'Korean man named Ji Hoon. Despite his anger '
#                                'and humiliation, he takes her out to dinner '
#                                'since she has lost all her money, and in '
#                                'return, she agrees to model for his amateur '
#                                'film. What follows is a magical and romantic '
#                                'two days. Upon returning to their respective '
#                                'countries, Tomoko must return to her '
#                                'nine-to-five job and Ji Hoon must resume '
#                                'studying to join the family business rather '
#                                'than pursuing his dream of becoming a film '
#                                'director. But soon the two begin to email each '
#                                'other and rekindle their relationship despite '
#                                'the distance and obstacles between them. '
#                                'Marking the very first time in television '
#                                'history that a drama has been co-produced '
#                                'between Japan and South Korea, the story shows '
#                                'us that love has no borders.</p>',
#                     'type': 'Scripted',
#                     'updated': 1505768726,
#                     'url': 'http://www.tvmaze.com/shows/30774/friends',
#                     'webChannel': None,
#                     'weight': 0}},
#     {   'score': 12.475377,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1298694'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/9965'}},
#                     'externals': {   'imdb': None,
#                                      'thetvdb': None,
#                                      'tvrage': None},
#                     'genres': [],
#                     'id': 9965,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/34/85499.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/34/85499.jpg'},
#                     'language': 'English',
#                     'name': 'FOX & Friends',
#                     'network': {   'country': {   'code': 'US',
#                                                   'name': 'United States',
#                                                   'timezone': 'America/New_York'},
#                                    'id': 185,
#                                    'name': 'FOX News Channel'},
#                     'officialSite': 'http://www.foxnews.com/on-air/fox-and-friends/',
#                     'premiered': '1996-10-07',
#                     'rating': {'average': None},
#                     'runtime': 180,
#                     'schedule': {   'days': [   'Monday',
#                                                 'Tuesday',
#                                                 'Wednesday',
#                                                 'Thursday',
#                                                 'Friday'],
#                                     'time': '06:00'},
#                     'status': 'Running',
#                     'summary': '<p><b>FOX &amp; Friends</b> is a conservative '
#                                'American early-morning news and opinion talk '
#                                'show on the Fox News Channel. It begins at '
#                                '6:00 a.m. Eastern Time with the latest <i>Fox '
#                                'News Live</i> headlines and news of the '
#                                'morning and continues with a variety of '
#                                'segments including current events, interviews, '
#                                'updates of news stories with correspondents, '
#                                'right-leaning analysis from the hosts, and '
#                                'entertainment segments.</p>',
#                     'type': 'News',
#                     'updated': 1530162043,
#                     'url': 'http://www.tvmaze.com/shows/9965/fox-friends',
#                     'webChannel': None,
#                     'weight': 0}},
#     {   'score': 12.170658,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/379663'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/6452'}},
#                     'externals': {   'imdb': 'tt0094469',
#                                      'thetvdb': 77054,
#                                      'tvrage': 3644},
#                     'genres': ['Children'],
#                     'id': 6452,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/24/61750.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/24/61750.jpg'},
#                     'language': 'English',
#                     'name': 'Garfield and Friends',
#                     'network': {   'country': {   'code': 'US',
#                                                   'name': 'United States',
#                                                   'timezone': 'America/New_York'},
#                                    'id': 2,
#                                    'name': 'CBS'},
#                     'officialSite': None,
#                     'premiered': '1988-09-17',
#                     'rating': {'average': None},
#                     'runtime': 30,
#                     'schedule': {   'days': [   'Monday',
#                                                 'Tuesday',
#                                                 'Wednesday',
#                                                 'Thursday',
#                                                 'Friday',
#                                                 'Saturday',
#                                                 'Sunday'],
#                                     'time': '02:00'},
#                     'status': 'Ended',
#                     'summary': '<p>An animated television series based on the '
#                                'comic strip Garfield by Jim Davis.</p>',
#                     'type': 'Animation',
#                     'updated': 1505357449,
#                     'url': 'http://www.tvmaze.com/shows/6452/garfield-and-friends',
#                     'webChannel': None,
#                     'weight': 0}},
#     {   'score': 11.883363,
#         'show': {   '_links': {   'nextepisode': {   'href': 'http://api.tvmaze.com/episodes/1514622'},
#                                   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1514621'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/4867'}},
#                     'externals': {   'imdb': None,
#                                      'thetvdb': 264210,
#                                      'tvrage': None},
#                     'genres': ['Nature'],
#                     'id': 4867,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/82/206116.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/82/206116.jpg'},
#                     'language': 'English',
#                     'name': 'Unlikely Animal Friends',
#                     'network': {   'country': {   'code': 'US',
#                                                   'name': 'United States',
#                                                   'timezone': 'America/New_York'},
#                                    'id': 5,
#                                    'name': 'The CW'},
#                     'officialSite': 'http://channel.nationalgeographic.com/wild/unlikely-animal-friends/',
#                     'premiered': '2012-11-23',
#                     'rating': {'average': None},
#                     'runtime': 30,
#                     'schedule': {'days': ['Saturday'], 'time': '11:30'},
#                     'status': 'Running',
#                     'summary': '<p>Friends are there for you when you need a '
#                                'shoulder to lean on. But who says only humans '
#                                'have friends? Join us for <b>Unlikely Animal '
#                                'Friends.</b></p>',
#                     'type': 'Reality',
#                     'updated': 1534873354,
#                     'url': 'http://www.tvmaze.com/shows/4867/unlikely-animal-friends',
#                     'webChannel': None,
#                     'weight': 92}},
#     {   'score': 11.660339,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/1199565'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/20345'}},
#                     'externals': {   'imdb': None,
#                                      'thetvdb': 328972,
#                                      'tvrage': None},
#                     'genres': ['Comedy'],
#                     'id': 20345,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/116/292483.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/116/292483.jpg'},
#                     'language': 'English',
#                     'name': 'Friends from College',
#                     'network': None,
#                     'officialSite': 'https://www.netflix.com/title/80117485',
#                     'premiered': '2017-07-14',
#                     'rating': {'average': 5.1},
#                     'runtime': 30,
#                     'schedule': {'days': ['Friday'], 'time': ''},
#                     'status': 'Running',
#                     'summary': '<p>As they face down their forties, a group of '
#                                'friends who met at Harvard experiences a range '
#                                'of success -- or lack thereof -- in this '
#                                'comedy series.</p>',
#                     'type': 'Scripted',
#                     'updated': 1533812914,
#                     'url': 'http://www.tvmaze.com/shows/20345/friends-from-college',
#                     'webChannel': {'country': None, 'id': 1, 'name': 'Netflix'},
#                     'weight': 81}},
#     {   'score': 11.519895,
#         'show': {   '_links': {   'previousepisode': {   'href': 'http://api.tvmaze.com/episodes/849684'},
#                                   'self': {   'href': 'http://api.tvmaze.com/shows/9862'}},
#                     'externals': {   'imdb': 'tt3590052',
#                                      'thetvdb': 281060,
#                                      'tvrage': None},
#                     'genres': ['Comedy'],
#                     'id': 9862,
#                     'image': {   'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/33/84898.jpg',
#                                  'original': 'http://static.tvmaze.com/uploads/images/original_untouched/33/84898.jpg'},
#                     'language': 'English',
#                     'name': 'Dinner with Friends with Brett Gelman and Friends',
#                     'network': {   'country': {   'code': 'US',
#                                                   'name': 'United States',
#                                                   'timezone': 'America/New_York'},
#                                    'id': 10,
#                                    'name': 'Adult Swim'},
#                     'officialSite': None,
#                     'premiered': '2014-04-24',
#                     'rating': {'average': None},
#                     'runtime': 22,
#                     'schedule': {'days': [], 'time': ''},
#                     'status': 'Ended',
#                     'summary': '<p>"You are cordially invited to join Brett '
#                                'Gelman and his Hollywood friends for a lively '
#                                'night of dining, tasty showbiz chit-chat, and '
#                                'psychological torture".</p>',
#                     'type': 'Scripted',
#                     'updated': 1497457736,
#                     'url': 'http://www.tvmaze.com/shows/9862/dinner-with-friends-with-brett-gelman-and-friends',
#                     'webChannel': None,
#                     'weight': 0}}]

# %%
# Print the following keys from the response JSON.
    # "Show name:" Name
    # "Show score:" Score
    # "Show rating:" Rating
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-83d9f02fad8b> in <module>()
#       4     # "Show rating:" Rating
#       5
# ----> 6 print(res_data["score"])
#       7
#
# TypeError: list indices must be integers or slices, not str

# %%
# Loop through each item from the response and print the show's name and rating.
    # "Show name: " Name
    # "Show rating:" Rating
# Out:
# Show name: Friends
# Show rating: 8.7
# Show name: LEGO Friends
# Show rating: None
# Show name: Thomas & Friends
# Show rating: None
# Show name: Jane & Friends
# Show rating: None
# Show name: Friends
# Show rating: None
# Show name: Super Friends
# Show rating: None
# Show name: Battlefield Friends
# Show rating: None
# Show name: Garfield and Friends
# Show rating: None
# Show name: Unlikely Animal Friends
# Show rating: None
# Show name: Friends from College
# Show rating: 5.1
